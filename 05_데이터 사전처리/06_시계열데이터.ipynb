# %%
import pandas as pd
df=pd.read_csv('./data/stock-data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
#문자열을 타임스탬프로 변환
df['new_Date']=pd.to_datetime(df['Date'])
print(df.head())
print('*'*60)
print(df.info())
print('*'*60)
print(type(df['new_Date'][0]))
print(type(df['new_Date']))
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20 non-null     object
#  1   Close     20 non-null     int64
#  2   Start     20 non-null     int64
#  3   High      20 non-null     int64
#  4   Low       20 non-null     int64
#  5   Volume    20 non-null     int64
#  6   new_Date  20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.2+ KB
# None
# ************************************************************
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas.core.series.Series'>

# %%
df = df.set_index('new_Date')
df = df.drop('Date', axis=1)

# 데이터 내용 및 자료형 자료형 확인
print(df.head())
print('\n')
print(df.info())
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  10800  10900  11000  10700   63039
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2018-07-02 to 2018-06-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   20 non-null     int64
#  1   Start   20 non-null     int64
#  2   High    20 non-null     int64
#  3   Low     20 non-null     int64
#  4   Volume  20 non-null     int64
# dtypes: int64(5)
# memory usage: 960.0 bytes
# None

# %%
pd.DatetimeIndex(["2022-12-25", "2023/01/25"])
# Out:
# DatetimeIndex(['2022-12-25', '2023-01-25'], dtype='datetime64[ns]', freq=None)

# %%
pd.Timestamp("2023-12-25")
# Out:
# Timestamp('2023-12-25 00:00:00')

# %%
pd.to_datetime("2023년 12월 25일", format="%Y년 %m월 %d일")
# Out:
# Timestamp('2023-12-25 00:00:00')

# %%
pd.to_datetime("12-12-2023 23:59:59", format="%d-%m-%Y %H:%M:%S")
# Out:
# Timestamp('2023-12-12 23:59:59')

# %%
import pandas as pd
dates = ['2019-01-01', '2020-03-01', '2021-06-01']
ts_dates = pd.to_datetime(dates)   
print(ts_dates)
#년도 월 일 
pr_day = ts_dates.to_period(freq='D')
print(pr_day)
#년도 월
pr_month = ts_dates.to_period(freq='M')
print(pr_month)
#년도
pr_year = ts_dates.to_period(freq='Y')
print(pr_year)
# Out:
# DatetimeIndex(['2019-01-01', '2020-03-01', '2021-06-01'], dtype='datetime64[ns]', freq=None)
# PeriodIndex(['2019-01-01', '2020-03-01', '2021-06-01'], dtype='period[D]')
# PeriodIndex(['2019-01', '2020-03', '2021-06'], dtype='period[M]')
# PeriodIndex(['2019', '2020', '2021'], dtype='period[Y-DEC]')

# %%
ts_ms = pd.date_range(start='2024-01-01',    # 날짜 범위의 시작
                   end=None,                 # 날짜 범위의 끝
                   periods=6,                # 생성할 Timestamp의 개수
                   freq='MS',                # 시간 간격 (MS: 월의 시작일)
                   tz='Asia/Seoul')          # 시간대(timezone)

print(ts_ms)
# Out:
# DatetimeIndex(['2024-01-01 00:00:00+09:00', '2024-02-01 00:00:00+09:00',
#                '2024-03-01 00:00:00+09:00', '2024-04-01 00:00:00+09:00',
#                '2024-05-01 00:00:00+09:00', '2024-06-01 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='MS')

# %%
ts_me = pd.date_range('2024-01-01', periods=6, 
                       freq='ME',              # 시간 간격 (ME: 월의 마지막 날)
                       tz='Asia/Seoul')        # 시간대(timezone)
print(ts_me)
# Out:
# DatetimeIndex(['2024-01-31 00:00:00+09:00', '2024-02-29 00:00:00+09:00',
#                '2024-03-31 00:00:00+09:00', '2024-04-30 00:00:00+09:00',
#                '2024-05-31 00:00:00+09:00', '2024-06-30 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='ME')

# %%
ts_3m = pd.date_range('2024-01-01',periods=6, 
                       freq='3MS',             # 시간 간격 (3MS: 3개월)
                       tz='Asia/Seoul')        # 시간대(timezone)
print(ts_3m)
# Out:
# DatetimeIndex(['2024-01-01 00:00:00+09:00', '2024-04-01 00:00:00+09:00',
#                '2024-07-01 00:00:00+09:00', '2024-10-01 00:00:00+09:00',
#                '2025-01-01 00:00:00+09:00', '2025-04-01 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='3MS')

# %%
# 라이브러리 불러오기
import pandas as pd

# Period 배열 만들기 - 1개월 주기
pr_m = pd.period_range(start='2024-01-01',     # 날짜 범위의 시작
                   end=None,                   # 날짜 범위의 끝
                   periods=3,                  # 생성할 Period 개수
                   freq='M')                   # 주기 (M: 월)
print(pr_m)
# Out:
# PeriodIndex(['2024-01', '2024-02', '2024-03'], dtype='period[M]')

# %%
# Period 배열 만들기 - 1시간 주기
pr_h = pd.period_range(start='2024-01-01',     # 날짜 범위의 시작
                   end=None,                   # 날짜 범위의 끝
                   periods=3,                  # 생성할 Period 개수
                   freq='h')                   # 주기 (h: 시간)
print(pr_h)
# Out:
# PeriodIndex(['2024-01-01 00:00', '2024-01-01 01:00', '2024-01-01 02:00'], dtype='period[h]')

# %%
# Period 배열 만들기 - 2일 주기
pr_2h = pd.period_range(start='2024-01-01',    # 날짜 범위의 시작
                   end=None,                   # 날짜 범위의 끝
                   periods=3,                  # 생성할 Period 개수
                   freq='2d')                  # 주기 (2d: 2일)
print(pr_2h)
# Out:
# PeriodIndex(['2024-01-01', '2024-01-03', '2024-01-05'], dtype='period[2D]')

# %%
import pandas as pd
df = pd.read_csv('./data/stock-data.csv')

# 문자열인 날짜 데이터를 판다스 Timestamp로 변환
df['new_Date'] = pd.to_datetime(df['Date'])   #df에 새로운 열로 추가
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26

# %%
df['Year'] = df['new_Date'].dt.year
df['Month'] = df['new_Date'].dt.month
df['Day'] = df['new_Date'].dt.day
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date  Year  Month  Day
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02  2018      7    2
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6   29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6   28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6   27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6   26

# %%
df['Date_yr'] = df['new_Date'].dt.to_period(freq='Y')
df['Date_m'] = df['new_Date'].dt.to_period(freq='M')
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date  Year  Month  \
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02  2018      7
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6
#
#    Day Date_yr   Date_m
# 0    2    2018  2018-07
# 1   29    2018  2018-06
# 2   28    2018  2018-06
# 3   27    2018  2018-06
# 4   26    2018  2018-06

# %%
# 2018년 6월 데이터만 추출 (문자열 속성 활용)
df_june = df[df['Date_m'].astype(str).str.fullmatch('2018-06')]
df_june.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date  Year  Month  \
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6
# 5  2018-06-25  11150  11400  11450  11000   55519 2018-06-25  2018      6
#
#    Day Date_yr   Date_m
# 1   29    2018  2018-06
# 2   28    2018  2018-06
# 3   27    2018  2018-06
# 4   26    2018  2018-06
# 5   25    2018  2018-06

# %%
# 2018년 6월 데이터만 추출 (Period 객체 활용)
df_june2 = df[df['Date_m'] == pd.Period('2018-06')]
df_june2.head()
# Out:
#          Date  Close  Start   High    Low  Volume   new_Date  Year  Month  \
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29  2018      6
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28  2018      6
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27  2018      6
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26  2018      6
# 5  2018-06-25  11150  11400  11450  11000   55519 2018-06-25  2018      6
#
#    Day Date_yr   Date_m
# 1   29    2018  2018-06
# 2   28    2018  2018-06
# 3   27    2018  2018-06
# 4   26    2018  2018-06
# 5   25    2018  2018-06

# %%
# 원하는 열을 새로운 행 인덱스로 지정
df_june = df_june.set_index('new_Date')
df_june.head()
# Out:
#                   Date  Close  Start   High    Low  Volume  Year  Month  Day  \
# new_Date
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253  2018      6   29
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769  2018      6   28
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548  2018      6   27
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039  2018      6   26
# 2018-06-25  2018-06-25  11150  11400  11450  11000   55519  2018      6   25
#
#            Date_yr   Date_m
# new_Date
# 2018-06-29    2018  2018-06
# 2018-06-28    2018  2018-06
# 2018-06-27    2018  2018-06
# 2018-06-26    2018  2018-06
# 2018-06-25    2018  2018-06

# %%
# 라이브러리 불러오기
import pandas as pd

# read_csv() 함수로 파일 읽어와서 df로 변환
df = pd.read_csv('./data/stock-data.csv')

# 문자열인 날짜 데이터를 판다스 Timestamp로 변환
df['new_Date'] = pd.to_datetime(df['Date'])   #df에 새로운 열로 추가

# 원하는 열을 새로운 행 인덱스로 지정하고 오름차순 정렬
df = df.set_index('new_Date').sort_index()

print(df.head())
print('\n')
print(df.index)
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  2018-06-04  11900  11900  12200  11700   25171
# 2018-06-05  2018-06-05  12150  11800  12250  11800   42485
# 2018-06-07  2018-06-07  11950  12200  12300  11900   49088
# 2018-06-08  2018-06-08  11950  11950  12200  11800   59258
#
#
# DatetimeIndex(['2018-06-01', '2018-06-04', '2018-06-05', '2018-06-07',
#                '2018-06-08', '2018-06-11', '2018-06-12', '2018-06-14',
#                '2018-06-15', '2018-06-18', '2018-06-19', '2018-06-20',
#                '2018-06-21', '2018-06-22', '2018-06-25', '2018-06-26',
#                '2018-06-27', '2018-06-28', '2018-06-29', '2018-07-02'],
#               dtype='datetime64[ns]', name='new_Date', freq=None)

# %%
df.loc['2018-06-27']
# Out:
# Date      2018-06-27
# Close          10900
# Start          10800
# High           11050
# Low            10500
# Volume        133548
# Name: 2018-06-27 00:00:00, dtype: object

# %%
df.loc['2018-07']
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
df.loc['2018-06-27':'2018-07-02']
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
df[df.index < '2018-06-05']
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  2018-06-04  11900  11900  12200  11700   25171

# %%
#시간인덱스활용
df.loc[pd.Timestamp(2018, 6, 27):pd.Timestamp(2018, 7, 2)]
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
df.loc[pd.Timestamp(2018, 6, 27, 10, 30, 0):pd.Timestamp(2018, 7, 2, 23, 59, 59)]
# Out:
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977

# %%
# 날짜, 시간의 절대적 차이 1
print(pd.Timedelta("1 days"))
print(pd.Timedelta(days=1))
print(pd.Timedelta("1 days 1 hours 1 minutes, 1 seconds"))
print(pd.Timedelta(days=1, hours=1, minutes=1, seconds=1))
# Out:
# 1 days 00:00:00
# 1 days 00:00:00
# 1 days 01:01:01
# 1 days 01:01:01
# C:\Users\KDS13\AppData\Local\Temp\ipykernel_23384\2732221366.py:2: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   print(pd.Timedelta("1 days"))
# C:\Users\KDS13\AppData\Local\Temp\ipykernel_23384\2732221366.py:3: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   print(pd.Timedelta(days=1))
# C:\Users\KDS13\AppData\Local\Temp\ipykernel_23384\2732221366.py:4: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   print(pd.Timedelta("1 days 1 hours 1 minutes, 1 seconds"))
# C:\Users\KDS13\AppData\Local\Temp\ipykernel_23384\2732221366.py:5: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   print(pd.Timedelta(days=1, hours=1, minutes=1, seconds=1))

# %%
pd.to_timedelta(["1 days", "3 hours"])
# Out:
# TimedeltaIndex(['1 days 00:00:00', '0 days 03:00:00'], dtype='timedelta64[ns]', freq=None)

# %%
# 날짜, 시간의 절대적 차이 3
a = df.index
print(a)

b = pd.Timestamp('2018-07-03') - a
print(b)

c = a + pd.Timedelta(days=1)
print(c)

print(c.min())
print(c.max())
# Out:
# DatetimeIndex(['2018-06-01', '2018-06-04', '2018-06-05', '2018-06-07',
#                '2018-06-08', '2018-06-11', '2018-06-12', '2018-06-14',
#                '2018-06-15', '2018-06-18', '2018-06-19', '2018-06-20',
#                '2018-06-21', '2018-06-22', '2018-06-25', '2018-06-26',
#                '2018-06-27', '2018-06-28', '2018-06-29', '2018-07-02'],
#               dtype='datetime64[ns]', name='new_Date', freq=None)
# TimedeltaIndex(['32 days', '29 days', '28 days', '26 days', '25 days',
#                 '22 days', '21 days', '19 days', '18 days', '15 days',
#                 '14 days', '13 days', '12 days', '11 days',  '8 days',
#                  '7 days',  '6 days',  '5 days',  '4 days',  '1 days'],
#                dtype='timedelta64[ns]', name='new_Date', freq=None)
# DatetimeIndex(['2018-06-02', '2018-06-05', '2018-06-06', '2018-06-08',
#                '2018-06-09', '2018-06-12', '2018-06-13', '2018-06-15',
#                '2018-06-16', '2018-06-19', '2018-06-20', '2018-06-21',
#                '2018-06-22', '2018-06-23', '2018-06-26', '2018-06-27',
#                '2018-06-28', '2018-06-29', '2018-06-30', '2018-07-03'],
#               dtype='datetime64[ns]', name='new_Date', freq=None)
# 2018-06-02 00:00:00
# 2018-07-03 00:00:00
# C:\Users\KDS13\AppData\Local\Temp\ipykernel_23384\109324012.py:8: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   c = a + pd.Timedelta(days=1)

# %%
#시계열 변환
import pandas as pd
df = pd.read_csv('./data/stock-data.csv')

# 문자열인 날짜 데이터를 판다스 Timestamp로 변환
df['new_Date'] = pd.to_datetime(df['Date'])  
df = df.drop(columns=['Date'])

# 원하는 열을 새로운 행 인덱스로 지정하고 오름차순 정렬
df = df.set_index('new_Date').sort_index()

ts = df.head(10)
ts
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  11900  11900  12200  11700   25171
# 2018-06-05  12150  11800  12250  11800   42485
# 2018-06-07  11950  12200  12300  11900   49088
# 2018-06-08  11950  11950  12200  11800   59258
# 2018-06-11  11950  12000  12250  11950   62293
# 2018-06-12  13200  12200  13300  12050  558148
# 2018-06-14  13450  13200  13700  13150  347451
# 2018-06-15  13400  13600  13600  12900  201376
# 2018-06-18  12000  13400  13400  12000  309787

# %%
ts.shift(1)
# Out:
#               Close    Start     High      Low    Volume
# new_Date
# 2018-06-01      NaN      NaN      NaN      NaN       NaN
# 2018-06-04  11900.0  11800.0  12100.0  11750.0   32062.0
# 2018-06-05  11900.0  11900.0  12200.0  11700.0   25171.0
# 2018-06-07  12150.0  11800.0  12250.0  11800.0   42485.0
# 2018-06-08  11950.0  12200.0  12300.0  11900.0   49088.0
# 2018-06-11  11950.0  11950.0  12200.0  11800.0   59258.0
# 2018-06-12  11950.0  12000.0  12250.0  11950.0   62293.0
# 2018-06-14  13200.0  12200.0  13300.0  12050.0  558148.0
# 2018-06-15  13450.0  13200.0  13700.0  13150.0  347451.0
# 2018-06-18  13400.0  13600.0  13600.0  12900.0  201376.0

# %%
ts.shift(-2)
# Out:
#               Close    Start     High      Low    Volume
# new_Date
# 2018-06-01  12150.0  11800.0  12250.0  11800.0   42485.0
# 2018-06-04  11950.0  12200.0  12300.0  11900.0   49088.0
# 2018-06-05  11950.0  11950.0  12200.0  11800.0   59258.0
# 2018-06-07  11950.0  12000.0  12250.0  11950.0   62293.0
# 2018-06-08  13200.0  12200.0  13300.0  12050.0  558148.0
# 2018-06-11  13450.0  13200.0  13700.0  13150.0  347451.0
# 2018-06-12  13400.0  13600.0  13600.0  12900.0  201376.0
# 2018-06-14  12000.0  13400.0  13400.0  12000.0  309787.0
# 2018-06-15      NaN      NaN      NaN      NaN       NaN
# 2018-06-18      NaN      NaN      NaN      NaN       NaN

# %%
# 날짜 데이터를 전부 이동
ts.shift(3, freq="D")
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-04  11900  11800  12100  11750   32062
# 2018-06-07  11900  11900  12200  11700   25171
# 2018-06-08  12150  11800  12250  11800   42485
# 2018-06-10  11950  12200  12300  11900   49088
# 2018-06-11  11950  11950  12200  11800   59258
# 2018-06-14  11950  12000  12250  11950   62293
# 2018-06-15  13200  12200  13300  12050  558148
# 2018-06-17  13450  13200  13700  13150  347451
# 2018-06-18  13400  13600  13600  12900  201376
# 2018-06-21  12000  13400  13400  12000  309787

# %%
# Frequency 전환
ts.asfreq('5D')
# Out:
#               Close    Start     High      Low   Volume
# new_Date
# 2018-06-01  11900.0  11800.0  12100.0  11750.0  32062.0
# 2018-06-06      NaN      NaN      NaN      NaN      NaN
# 2018-06-11  11950.0  12000.0  12250.0  11950.0  62293.0
# 2018-06-16      NaN      NaN      NaN      NaN      NaN

# %%
ts.asfreq('5D', method='bfill')
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  11900  11800  12100  11750   32062
# 2018-06-06  11950  12200  12300  11900   49088
# 2018-06-11  11950  12000  12250  11950   62293
# 2018-06-16  12000  13400  13400  12000  309787

# %%
# Resampling
print(ts.resample("3B"))

ts.resample("3B").sum()
# Out:
# DatetimeIndexResampler [freq=<3 * BusinessDays>, axis=0, closed=left, label=left, convention=start, origin=start_day]
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  35950  35500  36550  35250   99718
# 2018-06-06  23900  24150  24500  23700  108346
# 2018-06-11  25150  24200  25550  24000  620441
# 2018-06-14  38850  40200  40700  38050  858614

# %%
# Window Operation (데이터 개수를 기준)
ts.rolling(window=3).sum()
# Out:
#               Close    Start     High      Low     Volume
# new_Date
# 2018-06-01      NaN      NaN      NaN      NaN        NaN
# 2018-06-04      NaN      NaN      NaN      NaN        NaN
# 2018-06-05  35950.0  35500.0  36550.0  35250.0    99718.0
# 2018-06-07  36000.0  35900.0  36750.0  35400.0   116744.0
# 2018-06-08  36050.0  35950.0  36750.0  35500.0   150831.0
# 2018-06-11  35850.0  36150.0  36750.0  35650.0   170639.0
# 2018-06-12  37100.0  36150.0  37750.0  35800.0   679699.0
# 2018-06-14  38600.0  37400.0  39250.0  37150.0   967892.0
# 2018-06-15  40050.0  39000.0  40600.0  38100.0  1106975.0
# 2018-06-18  38850.0  40200.0  40700.0  38050.0   858614.0

# %%
# Window Operation (날짜 수를 기준)
ts.rolling(window='3D').sum()
# Out:
#               Close    Start     High      Low    Volume
# new_Date
# 2018-06-01  11900.0  11800.0  12100.0  11750.0   32062.0
# 2018-06-04  11900.0  11900.0  12200.0  11700.0   25171.0
# 2018-06-05  24050.0  23700.0  24450.0  23500.0   67656.0
# 2018-06-07  24100.0  24000.0  24550.0  23700.0   91573.0
# 2018-06-08  23900.0  24150.0  24500.0  23700.0  108346.0
# 2018-06-11  11950.0  12000.0  12250.0  11950.0   62293.0
# 2018-06-12  25150.0  24200.0  25550.0  24000.0  620441.0
# 2018-06-14  26650.0  25400.0  27000.0  25200.0  905599.0
# 2018-06-15  26850.0  26800.0  27300.0  26050.0  548827.0
# 2018-06-18  12000.0  13400.0  13400.0  12000.0  309787.0

# %%
#시계열 데이터 시각화
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# read_csv() 함수로 파일 읽어와서 df로 변환
df = pd.read_csv('./data/stock-data.csv')

# 문자열인 날짜 데이터를 판다스 Timestamp로 변환
df['new_Date'] = pd.to_datetime(df['Date'])  
df = df.drop(columns=['Date'])

# 원하는 열을 새로운 행 인덱스로 지정하고 오름차순 정렬
df = df.set_index('new_Date').sort_index()

df.head()
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-06-01  11900  11800  12100  11750   32062
# 2018-06-04  11900  11900  12200  11700   25171
# 2018-06-05  12150  11800  12250  11800   42485
# 2018-06-07  11950  12200  12300  11900   49088
# 2018-06-08  11950  11950  12200  11800   59258

# %%
# 종가(Close) 변화를 시각화 (시리즈 객체)
df['Close'].plot(figsize=(8, 3));

# %%
# 데이터프레임 전체 시각화
df.plot(figsize=(8, 3));

# %%
# 종가(Close)와 거래량(volume) 변화를 함께 시각화 
df[['Close', 'Volume']].plot(figsize=(8, 3));

# %%
# 보조축 표시
df["Close"].plot(label='Close', legend=True, figsize=(8, 3));
df["Volume"].plot(secondary_y=True, style="r", label='Volume', legend=True);

# %%
# 색상 맵 
df.plot(figsize=(8, 3), colormap="tab20");

# %%
# 그리드 레이아웃 - 서브 플롯 
axes = df.plot(subplots=True, layout=(2, 3), figsize=(18, 6), sharex=True, sharey=False)

# x 축의 주요 레이블 위치를 최대 5개로 제한
axes[0, 0].xaxis.set_major_locator(plt.MaxNLocator(5))

# %%
# Figure, Axes 객체
fig, axes = plt.subplots(nrows=2, ncols=2, 
                         figsize=(16, 8),
                         constrained_layout=True)

# 선 스타일
df['Close'].plot(ax=axes[0, 0], style="r-.")
axes[0, 0].set_title('Close')

# 로그 스케일 변환
df['Close'].plot(ax=axes[0, 1], logy=True)
axes[0, 1].set_title('Close (log)')

# 면적 그래프
df['Close'].plot(ax=axes[1, 0], kind='area', alpha=0.5)
axes[1, 0].set_title('Close (area)')

# 보조축 적용
df[['Start', 'High', 'Low', 'Close']].plot(ax=axes[1, 1], legend=True)
df['Volume'].plot(ax=axes[1, 1], legend=True, secondary_y=True)
axes[1, 1].set_title('Price/Volume')

plt.show()

# %%
import requests
import pandas as pd

my_key = "dpd-f9b30098-0fffe13acd6bf71c3020bcc0e2de2526fb63d2a93cf9347f57d8ee3c00d3b2b2"

# 특정 종목(stockCode)의 재무항목(indicatorName) 데이터를 가져오는 함수를 정의
def get_financials(stockCode, indicatorName, apiKey, consolidated=True, ttm=True):    
    if consolidated:   # 연결 기준
        if ttm:        # Trailing 12 Months (12개월 누적)
            url = f"https://api.dapada.io/company/getConsolidatedFinancialDataByTTM?indicatorName={indicatorName}&stockCode={stockCode}"
                        
        else:          # 해당 분기 기준 (3개월 집계)
            url = f"https://api.dapada.io/company/getConsolidatedFinancialDataByCUR?indicatorName={indicatorName}&stockCode={stockCode}"       
            
    else:              # 별도 기준
        if ttm:        # Trailing 12 Months (12개월 누적)
            url = f" https://api.dapada.io/company/getSeparatedFinancialDataByTTM?indicatorName={indicatorName}&stockCode={stockCode}"            
        else:          # 해당 분기 기준 (3개월 집계)
            url = f" https://api.dapada.io/company/getSeparatedFinancialDataByCUR?indicatorName={indicatorName}&stockCode={stockCode}"       
           
    headers = {"Authorization": f"{apiKey}"}
    response = requests.get(url, headers=headers)
    result = response.json()
    return pd.DataFrame(result)

# 삼성전자(005930)의 연결 재무제표 (TTM 기준)에서 "매출액" 항목의 데이터 수집
df_ttm_consolidated = get_financials(stockCode='005930',
                                     indicatorName='매출액',
                                     apiKey=my_key,
                                     consolidated=True,
                                     ttm=True)
df_ttm_consolidated
df_cur_consolidated = get_financials(stockCode='005930', 
                                     indicatorName='매출액', 
                                     apiKey=my_key, 
                                     consolidated=True, 
                                     ttm=False)

df_cur_consolidated
# Out:
#             value  quarter
# 0  67404652000000  2023-Q3
# 1  60005533000000  2023-Q2
# 2  63745371000000  2023-Q1
# 3  70464575000000  2022-Q4
# 4  76781680000000  2022-Q3
# 5  77203607000000  2022-Q2
# 6  77781498000000  2022-Q1

# %%
import requests
import pandas as pd

my_key = "dpd-f9b30098-0fffe13acd6bf71c3020bcc0e2de2526fb63d2a93cf9347f57d8ee3c00d3b2b2"

# 특정 종목(stockCode)의 재무항목(indicatorName) 데이터를 가져오는 함수를 정의
def get_financials(stockCode, indicatorName, apiKey, consolidated=True, ttm=True):    
    if consolidated:   # 연결 기준
        if ttm:        # Trailing 12 Months (12개월 누적)
            url = f"https://api.dapada.io/company/getConsolidatedFinancialDataByTTM?indicatorName={indicatorName}&stockCode={stockCode}"
                        
        else:          # 해당 분기 기준 (3개월 집계)
            url = f"https://api.dapada.io/company/getConsolidatedFinancialDataByCUR?indicatorName={indicatorName}&stockCode={stockCode}"       
            
    else:              # 별도 기준
        if ttm:        # Trailing 12 Months (12개월 누적)
            url = f" https://api.dapada.io/company/getSeparatedFinancialDataByTTM?indicatorName={indicatorName}&stockCode={stockCode}"            
        else:          # 해당 분기 기준 (3개월 집계)
            url = f" https://api.dapada.io/company/getSeparatedFinancialDataByCUR?indicatorName={indicatorName}&stockCode={stockCode}"       
           
    headers = {"Authorization": f"{apiKey}"}
    response = requests.get(url, headers=headers)
    result = response.json()
    return pd.DataFrame(result)

# 삼성전자(005930)의 연결 재무제표 (분기 기준)에서 '영업이익' 항목의 데이터 수집
df_samsung = get_financials(stockCode='005930', 
                            indicatorName='영업이익', 
                            apiKey=my_key, 
                            consolidated=True, 
                            ttm=False)

# 영업이익의 변화율을 계산
df_samsung['change'] = df_samsung['value'].pct_change()

# quarter 열을 인덱스로 설정
df_samsung = df_samsung.set_index('quarter')

# SK하이닉스(000660)의 연결 재무제표 (분기 기준)에서 '영업이익' 항목의 데이터 수집
df_skhynix = get_financials(stockCode='000660', 
                            indicatorName='영업이익', 
                            apiKey=my_key, 
                            consolidated=True, 
                            ttm=False)

# 영업이익의 변화율을 계산
df_skhynix['change'] = df_skhynix['value'].pct_change()

# quarter 열을 인덱스로 설정
df_skhynix = df_skhynix.set_index('quarter')

df_samsung
# Out:
#                   value    change
# quarter
# 2023-Q3   2433534000000       NaN
# 2023-Q2    668547000000 -0.725277
# 2023-Q1    640178000000 -0.042434
# 2022-Q4   4306131000000  5.726459
# 2022-Q3   9389198000000  1.180426
# 2022-Q2  11098805000000  0.182082
# 2022-Q1  11324628000000  0.020347

# %%
# 데이터 값의 형식을 지정 (소수정 이하 둘째 자리, 천 단위, 소수점 표시)
df_samsung.style.format(precision=2, thousands=',', decimal='.')
# Out:
# <style type="text/css">
# </style>
# <table id="T_24c24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24c24_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_24c24_level0_col1" class="col_heading level0 col1" >change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24c24_level0_row0" class="row_heading level0 row0" >2023-Q3</th>
#       <td id="T_24c24_row0_col0" class="data row0 col0" >2,433,534,000,000</td>
#       <td id="T_24c24_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_24c24_level0_row1" class="row_heading level0 row1" >2023-Q2</th>
#       <td id="T_24c24_row1_col0" class="data row1 col0" >668,547,000,000</td>
#       <td id="T_24c24_row1_col1" class="data row1 col1" >-0.73</td>
#     </tr>
#     <tr>
#       <th id="T_24c24_level0_row2" class="row_heading level0 row2" >2023-Q1</th>
#       <td id="T_24c24_row2_col0" class="data row2 col0" >640,178,000,000</td>
#       <td id="T_24c24_row2_col1" class="data row2 col1" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_24c24_level0_row3" class="row_heading level0 row3" >2022-Q4</th>
#       <td id="T_24c24_row3_col0" class="data row3 col0" >4,306,131,000,000</td>
#       <td id="T_24c24_row3_col1" class="data row3 col1" >5.73</td>
#     </tr>
#     <tr>
#       <th id="T_24c24_level0_row4" class="row_heading level0 row4" >2022-Q3</th>
#       <td id="T_24c24_row4_col0" class="data row4 col0" >9,389,198,000,000</td>
#       <td id="T_24c24_row4_col1" class="data row4 col1" >1.18</td>
#     </tr>
#     <tr>
#       <th id="T_24c24_level0_row5" class="row_heading level0 row5" >2022-Q2</th>
#       <td id="T_24c24_row5_col0" class="data row5 col0" >11,098,805,000,000</td>
#       <td id="T_24c24_row5_col1" class="data row5 col1" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_24c24_level0_row6" class="row_heading level0 row6" >2022-Q1</th>
#       <td id="T_24c24_row6_col0" class="data row6 col0" >11,324,628,000,000</td>
#       <td id="T_24c24_row6_col1" class="data row6 col1" >0.02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 데이터 값의 형식을 지정 (열 이름 대문자로 변환)
df_samsung.style.format_index(str.upper, axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b505e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b505e_level0_col0" class="col_heading level0 col0" >VALUE</th>
#       <th id="T_b505e_level0_col1" class="col_heading level0 col1" >CHANGE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b505e_level0_row0" class="row_heading level0 row0" >2023-Q3</th>
#       <td id="T_b505e_row0_col0" class="data row0 col0" >2433534000000</td>
#       <td id="T_b505e_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b505e_level0_row1" class="row_heading level0 row1" >2023-Q2</th>
#       <td id="T_b505e_row1_col0" class="data row1 col0" >668547000000</td>
#       <td id="T_b505e_row1_col1" class="data row1 col1" >-0.725277</td>
#     </tr>
#     <tr>
#       <th id="T_b505e_level0_row2" class="row_heading level0 row2" >2023-Q1</th>
#       <td id="T_b505e_row2_col0" class="data row2 col0" >640178000000</td>
#       <td id="T_b505e_row2_col1" class="data row2 col1" >-0.042434</td>
#     </tr>
#     <tr>
#       <th id="T_b505e_level0_row3" class="row_heading level0 row3" >2022-Q4</th>
#       <td id="T_b505e_row3_col0" class="data row3 col0" >4306131000000</td>
#       <td id="T_b505e_row3_col1" class="data row3 col1" >5.726459</td>
#     </tr>
#     <tr>
#       <th id="T_b505e_level0_row4" class="row_heading level0 row4" >2022-Q3</th>
#       <td id="T_b505e_row4_col0" class="data row4 col0" >9389198000000</td>
#       <td id="T_b505e_row4_col1" class="data row4 col1" >1.180426</td>
#     </tr>
#     <tr>
#       <th id="T_b505e_level0_row5" class="row_heading level0 row5" >2022-Q2</th>
#       <td id="T_b505e_row5_col0" class="data row5 col0" >11098805000000</td>
#       <td id="T_b505e_row5_col1" class="data row5 col1" >0.182082</td>
#     </tr>
#     <tr>
#       <th id="T_b505e_level0_row6" class="row_heading level0 row6" >2022-Q1</th>
#       <td id="T_b505e_row6_col0" class="data row6 col0" >11324628000000</td>
#       <td id="T_b505e_row6_col1" class="data row6 col1" >0.020347</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 데이터 값의 형식을 지정 (행 인덱스를 소문자로 변환)
df_samsung.style.format_index(str.lower, axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9bc16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bc16_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_9bc16_level0_col1" class="col_heading level0 col1" >change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bc16_level0_row0" class="row_heading level0 row0" >2023-q3</th>
#       <td id="T_9bc16_row0_col0" class="data row0 col0" >2433534000000</td>
#       <td id="T_9bc16_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9bc16_level0_row1" class="row_heading level0 row1" >2023-q2</th>
#       <td id="T_9bc16_row1_col0" class="data row1 col0" >668547000000</td>
#       <td id="T_9bc16_row1_col1" class="data row1 col1" >-0.725277</td>
#     </tr>
#     <tr>
#       <th id="T_9bc16_level0_row2" class="row_heading level0 row2" >2023-q1</th>
#       <td id="T_9bc16_row2_col0" class="data row2 col0" >640178000000</td>
#       <td id="T_9bc16_row2_col1" class="data row2 col1" >-0.042434</td>
#     </tr>
#     <tr>
#       <th id="T_9bc16_level0_row3" class="row_heading level0 row3" >2022-q4</th>
#       <td id="T_9bc16_row3_col0" class="data row3 col0" >4306131000000</td>
#       <td id="T_9bc16_row3_col1" class="data row3 col1" >5.726459</td>
#     </tr>
#     <tr>
#       <th id="T_9bc16_level0_row4" class="row_heading level0 row4" >2022-q3</th>
#       <td id="T_9bc16_row4_col0" class="data row4 col0" >9389198000000</td>
#       <td id="T_9bc16_row4_col1" class="data row4 col1" >1.180426</td>
#     </tr>
#     <tr>
#       <th id="T_9bc16_level0_row5" class="row_heading level0 row5" >2022-q2</th>
#       <td id="T_9bc16_row5_col0" class="data row5 col0" >11098805000000</td>
#       <td id="T_9bc16_row5_col1" class="data row5 col1" >0.182082</td>
#     </tr>
#     <tr>
#       <th id="T_9bc16_level0_row6" class="row_heading level0 row6" >2022-q1</th>
#       <td id="T_9bc16_row6_col0" class="data row6 col0" >11324628000000</td>
#       <td id="T_9bc16_row6_col1" class="data row6 col1" >0.020347</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 데이터 값의 형식을 지정 (열 이름을 재지정)
df_samsung.style.relabel_index(['영업이익', '영업이익증가율'], axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cdc5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdc5c_level0_col0" class="col_heading level0 col0" >영업이익</th>
#       <th id="T_cdc5c_level0_col1" class="col_heading level0 col1" >영업이익증가율</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdc5c_level0_row0" class="row_heading level0 row0" >2023-Q3</th>
#       <td id="T_cdc5c_row0_col0" class="data row0 col0" >2433534000000</td>
#       <td id="T_cdc5c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cdc5c_level0_row1" class="row_heading level0 row1" >2023-Q2</th>
#       <td id="T_cdc5c_row1_col0" class="data row1 col0" >668547000000</td>
#       <td id="T_cdc5c_row1_col1" class="data row1 col1" >-0.725277</td>
#     </tr>
#     <tr>
#       <th id="T_cdc5c_level0_row2" class="row_heading level0 row2" >2023-Q1</th>
#       <td id="T_cdc5c_row2_col0" class="data row2 col0" >640178000000</td>
#       <td id="T_cdc5c_row2_col1" class="data row2 col1" >-0.042434</td>
#     </tr>
#     <tr>
#       <th id="T_cdc5c_level0_row3" class="row_heading level0 row3" >2022-Q4</th>
#       <td id="T_cdc5c_row3_col0" class="data row3 col0" >4306131000000</td>
#       <td id="T_cdc5c_row3_col1" class="data row3 col1" >5.726459</td>
#     </tr>
#     <tr>
#       <th id="T_cdc5c_level0_row4" class="row_heading level0 row4" >2022-Q3</th>
#       <td id="T_cdc5c_row4_col0" class="data row4 col0" >9389198000000</td>
#       <td id="T_cdc5c_row4_col1" class="data row4 col1" >1.180426</td>
#     </tr>
#     <tr>
#       <th id="T_cdc5c_level0_row5" class="row_heading level0 row5" >2022-Q2</th>
#       <td id="T_cdc5c_row5_col0" class="data row5 col0" >11098805000000</td>
#       <td id="T_cdc5c_row5_col1" class="data row5 col1" >0.182082</td>
#     </tr>
#     <tr>
#       <th id="T_cdc5c_level0_row6" class="row_heading level0 row6" >2022-Q1</th>
#       <td id="T_cdc5c_row6_col0" class="data row6 col0" >11324628000000</td>
#       <td id="T_cdc5c_row6_col1" class="data row6 col1" >0.020347</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 데이터 값의 형식을 지정 (행 인덱스를 재지정)
new_dates = ['2023.09', '2023.06', '2023.03', '2022.12', '2022.09', '2022.06']
df_samsung.style.relabel_index(new_dates, axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 3
#       1 # 데이터 값의 형식을 지정 (행 인덱스를 재지정)
#       2 new_dates = ['2023.09', '2023.06', '2023.03', '2022.12', '2022.09', '2022.06']
# ----> 3 df_samsung.style.relabel_index(new_dates, axis=0)
#
# File c:\Users\KDS13\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\formats\style_render.py:1536, in StylerRenderer.relabel_index(self, labels, axis, level)
#    1534 visible_len = len(obj) - len(set(hidden_labels))
#    1535 if len(labels) != visible_len:
# -> 1536     raise ValueError(
#    1537         "``labels`` must be of length equal to the number of "
#    1538         f"visible labels along ``axis`` ({visible_len})."
#    1539     )
#    1541 if level is None:
#    1542     level = [i for i in range(obj.nlevels) if not hidden_lvls[i]]
#
# ValueError: ``labels`` must be of length equal to the number of visible labels along ``axis`` (7).
